# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Камиль, привет! Это Александр Матвеевский</b> Я рад тебя видеть на финальном спринте (SQL).
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от тимлида №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от тимлида №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если у тебя возникают вопросы — пиши об этом в пачке, не стесняйся. Так же, мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
#
# ---

# %% [markdown]
# # Проект по SQL

# %% [markdown]
# ## Описание проекта
# Коронавирус застал мир врасплох, изменив привычный порядок вещей. В свободное время жители городов больше не выходят на улицу, не посещают кафе и торговые центры. Зато стало больше времени для книг. Это заметили стартаперы — и бросились создавать приложения для тех, кто любит читать.
#
# Ваша компания решила быть на волне и купила крупный сервис для чтения книг по подписке. Ваша первая задача как аналитика — проанализировать базу данных.
# В ней — информация о книгах, издательствах, авторах, а также пользовательские обзоры книг. Эти данные помогут сформулировать ценностное предложение для нового продукта.

# %% [markdown]
# ## Описание данных
# **Таблица `books`**
#
# Содержит данные о книгах:
#
# - `book_id` — идентификатор книги;
# - `author_id` — идентификатор автора;
# - `title` — название книги;
# - `num_pages` — количество страниц;
# - `publication_date` — дата публикации книги;
# - `publisher_id` — идентификатор издателя.
#
# **Таблица `authors`**
#
# Содержит данные об авторах:
#
# - `author_id` — идентификатор автора;
# - `author` — имя автора.
#
# **Таблица `publishers`**
#
# Содержит данные об издательствах:
#
# - `publisher_id` — идентификатор издательства;
# - `publisher` — название издательства;
#
# **Таблица `ratings`**
#
# Содержит данные о пользовательских оценках книг:
#
# - `rating_id` — идентификатор оценки;
# - `book_id` — идентификатор книги;
# - `username` — имя пользователя, оставившего оценку;
# - `rating` — оценка книги.
#
# **Таблица `reviews`**
#
# Содержит данные о пользовательских обзорах на книги:
#
# - `review_id` — идентификатор обзора;
# - `book_id` — идентификатор книги;
# - `username` — имя пользователя, написавшего обзор;
# - `text` — текст обзора.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №1__
#
# Здорово, что не забываешь про оформление проекта
# </div>

# %%
# импортируем библиотеки
import pandas as pd
from sqlalchemy import text, create_engine

# устанавливаем параметры
db_config = {'user': 'praktikum_student', # имя пользователя
    'pwd': 'Sdf4$2;d-d30pp', # пароль
    'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
    'port': 6432, # порт подключения
    'db': 'data-analyst-final-project-db'} # название базы данных
connection_string = 'postgresql://{user}:{pwd}@{host}:{port}/{db}'.format(**db_config)

# сохраняем коннектор
engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# **Выведем первые 5 строк всех датафреймов**

# %%
query = '''SELECT * 
           FROM books
           LIMIT 5;
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    book_id  author_id                                              title  \
# 0        1        546                                       'Salem's Lot
# 1        2        465                 1 000 Places to See Before You Die
# 2        3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3        4         82  1491: New Revelations of the Americas Before C...
# 4        5        125                                               1776
#
#    num_pages publication_date  publisher_id
# 0        594       2005-11-01            93
# 1        992       2003-05-22           336
# 2        322       2010-12-21           135
# 3        541       2006-10-10           309
# 4        386       2006-07-04           268

# %%
query = '''SELECT *
           FROM authors
           LIMIT 5;
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    author_id                          author
# 0          1                      A.S. Byatt
# 1          2  Aesop/Laura Harris/Laura Gibbs
# 2          3                 Agatha Christie
# 3          4                   Alan Brennert
# 4          5        Alan Moore/David   Lloyd

# %%
query = '''SELECT * 
           FROM ratings
           LIMIT 5;
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    rating_id  book_id       username  rating
# 0          1        1     ryanfranco       4
# 1          2        1  grantpatricia       2
# 2          3        1   brandtandrea       5
# 3          4        2       lorichen       3
# 4          5        2    mariokeller       2

# %%
query = '''SELECT *
           FROM reviews
           LIMIT 5;
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    review_id  book_id       username  \
# 0          1        1   brandtandrea
# 1          2        1     ryanfranco
# 2          3        2       lorichen
# 3          4        3  johnsonamanda
# 4          5        3    scotttamara
#
#                                                 text
# 0  Mention society tell send professor analysis. ...
# 1  Foot glass pretty audience hit themselves. Amo...
# 2  Listen treat keep worry. Miss husband tax but ...
# 3  Finally month interesting blue could nature cu...
# 4  Nation purpose heavy give wait song will. List...

# %%
query = '''SELECT * 
           FROM publishers
           LIMIT 5;
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    publisher_id                          publisher
# 0             1                                Ace
# 1             2                           Ace Book
# 2             3                          Ace Books
# 3             4                      Ace Hardcover
# 4             5  Addison Wesley Publishing Company

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от тимлида №1__
#
# Отсутствует вывод первых строк

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил! </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №2__
#
# Отлично первый взгляд на данные есть. Ты корректно выгрузил данные и посмотрел их содержимое
# </div>

# %% [markdown]
# ### Задача 1. Посчитайте, сколько книг вышло после 1 января 2000 года.

# %%
query = '''SELECT COUNT(*) 
           FROM books
           WHERE publication_date > '2000-01-01'
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    count
# 0    819

# %% [markdown]
# После 1 января 2000 года вышло 819 книг.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №1__
#
# Расчёт верный
# </div>

# %% [markdown]
# ### Задача 2. Для каждой книги посчитайте количество обзоров и среднюю оценку.

# %%
query = '''SELECT b.title AS books_title,
                  COUNT(DISTINCT rev.review_id) AS review_count,
                  AVG(rat.rating) AS avg_rating
           FROM books AS b
           LEFT JOIN reviews AS rev ON b.book_id = rev.book_id
           LEFT JOIN ratings AS rat ON b.book_id = rat.book_id
           GROUP BY b.book_id
           ORDER BY avg_rating DESC, review_count DESC
           '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#                                            books_title  review_count  \
# 0                        A Dirty Job (Grim Reaper  #1)             4
# 1              School's Out—Forever (Maximum Ride  #2)             3
# 2         Moneyball: The Art of Winning an Unfair Game             3
# 3        Arrows of the Queen (Heralds of Valdemar  #1)             2
# 4    Wherever You Go  There You Are: Mindfulness Me...             2
# ..                                                 ...           ...
# 995  The World Is Flat: A Brief History of the Twen...             3
# 996                                      Drowning Ruth             3
# 997                  His Excellency: George Washington             2
# 998                                              Junky             2
# 999                               Harvesting the Heart             2
#
#      avg_rating
# 0          5.00
# 1          5.00
# 2          5.00
# 3          5.00
# 4          5.00
# ..          ...
# ...

# %% [markdown]
# Получили таблицу с названием книги, количеством обзора и средней оценки. Поэтой таблице можно сказать что книга с названием "Moneyball: The Art of Winning an Unfair Game" имеет 3 обзора, и среднюю оценку 5.00.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от тимлида №1__
#
# Здесь несколько ошибок:
#
#
# 1. Посчитай, пожалуйста, сколько всего ревью в БД (можно на 1 этапе), и посмотри какая сумма count_review после твоего запроса
#
# 2. Группируешь по Title, а не по ID (у нас 1000 книг изначально в данных)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Исправил!:) Но получается что, есть 2 книги в БД с одинаковым названием, но это разные книги и у них разный id? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №2__
#
# Да)), теперь всё корректно
# </div>

# %% [markdown]
# ### Задача 3. Определите издательство, которое выпустило наибольшее число книг толще 50 страниц — так вы исключите из анализа брошюры.

# %%
query = '''SELECT publisher
           FROM publishers
           WHERE publisher_id IN (SELECT publisher_id
                                  FROM books
                                  WHERE num_pages > 50
                                  GROUP BY publisher_id
                                  ORDER BY COUNT(book_id) DESC
                                  LIMIT 1)
        '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#        publisher
# 0  Penguin Books

# %% [markdown]
# Penguin Books - издательство, которое выпустило наибольшее число книг(без учета брошюр).

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №1__
#
# Согласен с результатом. Действительно данное издательство является лидером по выпущенным книгам
# </div>

# %% [markdown]
# ### Задача 4. Определите автора с самой высокой средней оценкой книг — учитывайте только книги с 50 и более оценками.

# %%
query = '''SELECT author
           FROM authors
           WHERE author_id IN (SELECT author_id
                               FROM books
                               WHERE book_id IN (SELECT book_id
                                                 FROM ratings
                                                 GROUP BY book_id
                                                 HAVING COUNT(rating) >= 50
                                                 ORDER BY AVG(rating) DESC
                                                 LIMIT 1)
                               )
        '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#                        author
# 0  J.K. Rowling/Mary GrandPré

# %% [markdown]
# J.K. Rowling/Mary GrandPré - автор с самой высокой средней оценкой книг(из числа книг с 50 и более оценками), а еще и автор книги о Гарри Поттере.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №1__
#
# После стольких лет? Всегда...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Задача 5. Посчитайте среднее количество обзоров от пользователей, которые поставили больше 48 оценок.

# %%
query = '''SELECT AVG(t1.review_count) AS avg_review
           FROM (SELECT COUNT(review_id) AS review_count
                 FROM reviews
                 WHERE username IN (SELECT username
                                    FROM ratings
                                    GROUP BY username
                                    HAVING COUNT(ratings) > 48)
                 GROUP BY username) AS t1
         '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_review
# 0        24.0

# %% [markdown]
# 24 - среднее количество обзоров от пользоватей, которые пославили больше 48 оценок.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от тимлида №1__
#
# Камиль. Откуда ты взял 50, когда в ТЗ 48?
#
# Прикладываю 2 доп. задачи, которые необходимо выполнить
#
# 1. Выведите таблицу, которая будет содержать по году публикации:
#
# - количество издательств,
# - выпущенных книг и
# - сколько всего тысяч страниц было в изданных книгах
#
# (отобразить только те года, в которых издано более 30 книг)
#
# 2. Выведите в одной таблице два числа — среднюю оценку тех книг, на которые написало отзывов более 3 человек и отдельно среднюю оценку остальных книг, сделайте выводы какой рейтинг больше
# </div>

# %% [markdown]
# #### Доп задача 1.

# %%
query = '''SELECT EXTRACT(YEAR FROM publication_date::date) AS publication_year,
                  COUNT(DISTINCT publisher_id) AS publisher_count,
                  COUNT(DISTINCT book_id) AS count_books,
                  ROUND(SUM(num_pages)/1000::NUMERIC, 1) AS pages_sum_thousand
           FROM books
           GROUP BY publication_year
           HAVING COUNT(DISTINCT book_id) > 30
           ORDER BY publication_year
           
        '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    publication_year  publisher_count  count_books  pages_sum_thousand
# 0            1999.0               26           41                15.8
# 1            2000.0               35           38                13.3
# 2            2001.0               41           60                21.8
# 3            2002.0               62           94                38.6
# 4            2003.0               65          105                41.4
# 5            2004.0               88          124                46.8
# 6            2005.0               89          139                56.0
# 7            2006.0              109          184                68.3
# 8            2007.0               38           50                18.3

# %%
query = '''WITH table_1 AS
                          (SELECT rating AS rating_more_3_users,
                                  book_id
                           FROM ratings
                           WHERE book_id IN (SELECT book_id
                                             FROM reviews
                                             GROUP BY book_id
                                             HAVING COUNT(DISTINCT username) > 3)),
                table_2 AS 
                          (SELECT rating AS rating_less_3_users,
                                  book_id
                           FROM ratings
                           WHERE book_id IN (SELECT book_id
                                             FROM reviews
                                             GROUP BY book_id
                                             HAVING COUNT(DISTINCT username) <= 3))
            SELECT AVG(table_1.rating_more_3_users) AS avg_rating_more,
                   AVG(table_2.rating_less_3_users) AS avg_rating_less
            FROM table_1
            FULL JOIN table_2 ON table_1.book_id = table_2.book_id;
                  
        '''

con=engine.connect()

pd.io.sql.read_sql(sql=text(query), con = con)
# Out:
#    avg_rating_more  avg_rating_less
# 0         3.949505         3.890191

# %% [markdown]
# Средний рейтинг книг, на которые написаны отзывы более чем 3мя людьми, выше среднего рейтинга книг, на которые написаны отзывы 3мя или менее людьми.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №2__
#
# Получилась хорошая работа. Поздравляю с окончанием курса! У тебя получилось справиться со всеми задачами.
# </div>
